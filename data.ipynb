# %%
from dhanhq import dhanhq
import datetime
import pandas as pd

API_TOKEN = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJpc3MiOiJkaGFuIiwicGFydG5lcklkIjoiIiwiZXhwIjoxNzMzOTc4OTk2LCJ0b2tlbkNvbnN1bWVyVHlwZSI6IlNFTEYiLCJ3ZWJob29rVXJsIjoiIiwiZGhhbkNsaWVudElkIjoiMTEwMjQ3ODI0NiJ9.yXepjbSK8de4xEmMvlmt0fjV-DMUeOKh-ugfQ-1XYIiOAfJ4AUvBYGde2jgZC2_RDhCoNsdobLusx2lk7atl0w"


CLIENT_ID = 1102478246





dhan = dhanhq(CLIENT_ID, API_TOKEN)

# %%
import pandas as pd

import matplotlib.pyplot as plt

import yfinance as yf

import mplfinance as mpf

from datetime import datetime

# %%
import mysql.connector
import redis
import json

# Establish a connection
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Vaibhav@123",
    database="stock_test"
)

# print(dir(conn))
# Create a cursor object to interact with the database
cursor = conn.cursor()

# Connect to Redis
redis_conn = redis.StrictRedis(host='localhost', port=6379, db=0)

# %%
import numpy as np
import datetime

# Define the time gap in minutes
time_gap = 10

# Function to calculate RSI (like TradingView)
def RSI(series, period=10):
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) # first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) # first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean()
    return 100 - 100 / (1 + rs)

# def RSI(series, period=14):
#     delta = series.diff().dropna()
#     gain = np.where(delta > 0, delta, 0)
#     loss = np.where(delta < 0, -delta, 0)
    
#     avg_gain = np.mean(gain[:period])
#     avg_loss = np.mean(loss[:period])
    
#     gain_series = pd.Series(np.append([np.nan] * (period - 1), gain))
#     loss_series = pd.Series(np.append([np.nan] * (period - 1), loss))
    
#     gain_ema = gain_series.ewm(com=period-1, min_periods=period).mean()
#     loss_ema = loss_series.ewm(com=period-1, min_periods=period).mean()
    
#     rs = gain_ema / loss_ema
#     rsi = 100 - (100 / (1 + rs))
#     return rsi

# Function to calculate Stochastic RSI (like TradingView)
def StochRSI(series, period=6, smoothK=3, smoothD=3):
    rsi = RSI(series, period)
    rsi_min = rsi.rolling(window=period).min()
    rsi_max = rsi.rolling(window=period).max()
    stoch_rsi = 100 * (rsi - rsi_min) / (rsi_max - rsi_min)

    k = stoch_rsi.rolling(window=smoothK).mean()  # %K line
    d = k.rolling(window=smoothD).mean()  # %D line

    return k, d

def check_sell_signal(df):
    # Get the last two rows (current and previous) of %K and %D values
    last_row = df.iloc[-1]
    prev_row = df.iloc[-2]

    # Condition 1: K line crossing D line from above
    k_cross_d = prev_row['%K'] > prev_row['%D'] and last_row['%K'] < last_row['%D']
    # print(prev_row['%K'],prev_row['%D'],last_row['%K'],last_row['%D'])
    
    # Condition 2: Difference between the current and previous K values is more than 7
    k_difference = abs(last_row['%K'] - prev_row['%D']) > 4
    
    valid = prev_row['%K'] > 10 and last_row['%K'] < 94

    is_crash = (last_row['%K'] <4  and  prev_row['%K'] >4)

    # Generate a sell signal if both conditions are met
    # removed : k_cross_d and k_difference and valid 
    if is_crash:
        print("Generated the signal bro :)")
        return True
    else:
        return False
    
def check_buy_signal(df):
    # Get the last two rows (current and previous) of %K and %D values
    last_row = df.iloc[-1]
    prev_row = df.iloc[-2]

    # Condition 1: K line crossing D line from above
    k_cross_d = prev_row['%K'] < prev_row['%D'] and last_row['%K'] > last_row['%D']
    # print(prev_row['%K'],prev_row['%D'],last_row['%K'],last_row['%D'])
    
    # Condition 2: Difference between the current and previous K values is more than 7
    k_difference = abs(last_row['%K'] - prev_row['%D']) > 4
    
    valid = prev_row['%K'] > 10 and prev_row['%K'] < 96

    is_rally = (prev_row['%K'] <95 and last_row['%K'] >98)

    # Generate a sell signal if both conditions are met
    if is_rally:
        return True
    else:
        return False
    

def get_data(date, symbol):
    start_time = pd.Timestamp(f'{date} 00:00:00')
    end_time = pd.Timestamp(f'{date} 23:59:59')
    data = yf.download(symbol, start=start_time, end=end_time, interval='5m')
    data = data.rename(columns={'Open': 'open', 'High': 'high', 'Low': 'low', 'Close': 'close', 'Volume': 'volume'})

    # Replace missing volume data with zero
    data['volume'] = data['volume'].fillna(0)

    data.index = data.index.tz_localize(None)
    # Reset index to 'start_Time'
    data.index.name = 'start_Time'

    # data = data.drop('Adj Close')
    # print(type(data))
    data  = data.drop(columns=['Adj Close'])
    return data

# Function to simulate signal generation
def generate_signal(stock_id, signal_type):
    current_time = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    if signal_type == 'sell':
        signal_data = {
            'stock_id': stock_id,
            'signal': 'S',
            'time': current_time
            
            
        }
        # Push the signal to Redis (could use a list or stream)
        redis_conn.rpush('stock_signals', json.dumps(signal_data))

    else:
        signal_data = {
            'stock_id': stock_id,
            'signal': 'B',
            'time': current_time
            
        }
        # Push the signal to Redis (could use a list or stream)
        redis_conn.rpush('stock_signals', json.dumps(signal_data))
        

def generate_signal_mysql(stock_id, signal_type,data_new):
    current_time = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

    # Check if the stock_id already exists in the signals table
    query = "SELECT time FROM stock_signals WHERE stock_name = %s"
    query_for_all_signals = "INSERT INTO all_signals (stock_name, stock_signal,time,pre_k,pre_d,last_k,last_d) VALUES (%s, %s,%s,%s,%s,%s,%s)"

    

    values = (stock_id, signal_type, current_time, float(data_new.iloc[-2]["%K"]), float(data_new.iloc[-2]["%D"]), float(data_new.iloc[-1]["%K"]), float(data_new.iloc[-1]["%D"]))

    cursor.execute(query_for_all_signals, values)

    conn.commit()
    cursor.execute(query, (stock_id,))
    result = cursor.fetchone()

    if result:
        # Stock exists, check time difference
        last_signal_time = result[0]
        last_signal_time = datetime.datetime.strptime(str(last_signal_time), '%Y-%m-%d %H:%M:%S')
        time_diff = datetime.datetime.now() - last_signal_time

        # If the time difference is less than or equal to time_gap, don't update
        if time_diff.total_seconds() <= time_gap * 60:
            print("Signal not updated: Time gap too small")
            return
        else:
            # Update the signal in the table
            update_query = "UPDATE stock_signals SET stock_signal = %s, time = %s WHERE stock_name = %s"
            signal = 'S' if signal_type == "sell" else 'B'
            cursor.execute(update_query, (signal, current_time, stock_id))
            conn.commit()
            print("Signal updated successfully")
    else:
        # Stock doesn't exist, insert a new signal
        insert_query = "INSERT INTO stock_signals (stock_name, stock_signal,time) VALUES (%s, %s,%s)"
        signal = "S" if signal_type == "sell" else "B"
        cursor.execute(insert_query, (stock_id, signal,current_time))
        conn.commit()
        print("Signal inserted successfully")


def aggregate_to_5min_df(data):
    # Resampling the data to 15-minute intervals
    data_5min = data.resample('5T').agg({
        'open': 'first',
        'high': 'max',
        'low': 'min',
        'close': 'last',
        'volume': 'sum'
    })
    
    # Dropping any rows where the 'open' value is missing (incomplete 15 min intervals)
    data_5min = data_5min.dropna(subset=['open'])
    
    return data_5min

def get_dhan_data(token_code):
    data = dhan.intraday_minute_data(
        security_id=token_code,
        exchange_segment='NSE_EQ',
        instrument_type='EQUITY'
    )
    # print(data)
    data = data['data']
    # print(da)
    df1 = pd.DataFrame(data)
    
    # print(df1)
    # print(data)
    df1['start_Time'] = df1['start_Time'].apply(dhan.convert_to_date_time)
    df1.set_index('start_Time', inplace=True)
    df1=aggregate_to_5min_df(df1)
    return df1
    # print(df.head(152))
    # data = aggregate_to_15min(data)
    # print("----------------------------------------------------------")
    # df = pd.DataFrame(data)
    # df['start_Time'] = df['start_Time'].apply(dhan.convert_to_date_time)
    # # df['start_Time'] = df['start_Time'].apply(dhan.convert_to_date_time)
    


def aggregate_to_15min_df(data):
    # Resampling the data to 15-minute intervals
    data_15min = data.resample('15T').agg({
        'open': 'first',
        'high': 'max',
        'low': 'min',
        'close': 'last',
        'volume': 'sum'
    })
    
    # Dropping any rows where the 'open' value is missing (incomplete 15 min intervals)
    data_15min = data_15min.dropna(subset=['open'])
    
    return data_15min


def update_data_mysql(date,ticker,df):
    # Iterate through each row in the DataFrame and insert/update in MySQL
    for timestamp, row in df.iterrows():
        timestamp = timestamp.to_pydatetime()

        # Convert all row values to native Python types
        open_val = float(row['open'])
        high_val = float(row['high'])
        low_val = float(row['low'])
        close_val = float(row['close'])
        volume_val = int(row['volume'])  # Assuming volume is an integer
        percent_k = float(row['%K'])
        percent_d = float(row["%D"])

        cursor.execute("""
            INSERT INTO stock_data_test_2 (ticker, date, timestamp, open, high, low, close, volume,percent_k,percent_d)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s,%s)
            ON DUPLICATE KEY UPDATE
                open = VALUES(open),
                high = VALUES(high),
                low = VALUES(low),
                close = VALUES(close),
                volume = VALUES(volume),
                percent_k = VALUES(percent_k),
                percent_d = VALUES(percent_d)
        """, (ticker, date, timestamp, open_val, high_val, low_val, close_val, volume_val,percent_k,percent_d))

    conn.commit()

def update_data_mysql_without_date(ticker,df):
    # Iterate through each row in the DataFrame and insert/update in MySQL
    for timestamp, row in df.iterrows():
        # timestamp = timestamp.to_pydatetime()
        if not isinstance(timestamp, datetime.datetime):
            timestamp = pd.to_datetime(timestamp)
        timestamp_str = timestamp.strftime('%Y-%m-%d %H:%M:%S')
            
        
        
        # Convert all row values to native Python types
        # date = timestamp
        # date = row['date']
        date = timestamp.date()  # Extract date from timestamp
        open_val = float(row['open'])
        high_val = float(row['high'])
        low_val = float(row['low'])
        close_val = float(row['close'])
        volume_val = int(row['volume'])  # Assuming volume is an integer
        percent_k = float(row['%K'])
        percent_d = float(row["%D"])

        cursor.execute("""
            INSERT INTO stock_data_test_2 (ticker, date, timestamp, open, high, low, close, volume,percent_k,percent_d)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s,%s)
            ON DUPLICATE KEY UPDATE
                open = VALUES(open),
                high = VALUES(high),
                low = VALUES(low),
                close = VALUES(close),
                volume = VALUES(volume),
                percent_k = VALUES(percent_k),
                percent_d = VALUES(percent_d)
        """, (ticker, date, timestamp, open_val, high_val, low_val, close_val, volume_val,percent_k,percent_d))

    conn.commit()



# def check_sell_signal(df):
#     # Get the last two rows (current and previous) of %K and %D values
#     last_row = df.iloc[-1]
#     prev_row = df.iloc[-2]

#     # Condition 1: K line crossing D line from above
#     k_cross_d = prev_row['%K'] > prev_row['%D'] and last_row['%K'] < last_row['%D']
#     # print(prev_row['%K'],prev_row['%D'],last_row['%K'],last_row['%D'])
    
#     # Condition 2: Difference between the current and previous K values is more than 7
#     k_difference = abs(last_row['%K'] - prev_row['%K']) > 2
    
#     valid = prev_row['%K'] > 55 and last_row['%K'] < 95

#     # Generate a sell signal if both conditions are met
#     if k_cross_d and k_difference and valid:
#         return True
#     else:
#         return False

# %%
import warnings




def get_stock_data_from_mysql(date: str, ticker: str) -> pd.DataFrame:
    
    
    # Query the data
    query = """
        SELECT timestamp AS start_Time, open, high, low, close, volume , percent_k , percent_d 
        FROM stock_data_test_2
        WHERE date = %s AND ticker = %s
        ORDER BY timestamp
    """
    # Use pandas to execute the query and load the data directly into a DataFrame
    df = pd.read_sql(query, conn, params=(date, ticker))
    
    # Rename columns 'percent_k' and 'percent_d' to '%K' and '%D'
    df.rename(columns={'percent_k': '%K', 'percent_d': '%D'}, inplace=True)


    # Set 'start_Time' as the index
    df.set_index('start_Time', inplace=True)
    
    return df


# Suppress specific pandas warnings
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore", category=UserWarning)
#     df = get_stock_data_from_mysql("2024-10-14","DLF.NS")
#     print(df)

# %% [markdown]
# # Code to put the data into mysql table

# %%
import time
import datetime



query_for_yf_names = "select yf_name from stocks"

cursor.execute(query_for_yf_names)


result = cursor.fetchall()

dates = [ "2024-10-14", "2024-10-15" , "2024-10-16" , "2024-10-17" , "2024-10-18" , "2024-10-21" ,"2024-10-22", "2024-10-23" , "2024-10-24"  ]


yf_name_list = [row[0] for row in result]


# Main loop to calculate RSI and update data for each stock
for stock_name in yf_name_list:
    combined_data = pd.DataFrame()

    # Fetch and combine data for each date
    for date in dates:
        data = get_data(date, stock_name)  # Function to fetch data
        combined_data = pd.concat([combined_data, data])

    combined_data = aggregate_to_15min_df(combined_data)  # Aggregation function
    # combined_data.reset_index(drop=True, inplace=True)

    # Calculate StochRSI and add to DataFrame
    combined_data['%K'], combined_data['%D'] = StochRSI(combined_data['close'])  # Assuming StochRSI function is defined

    # Remove stock suffix from name and update in MySQL
    stock_name_cleaned = stock_name[:-3]
    print(combined_data)
    update_data_mysql_without_date(stock_name_cleaned,combined_data)
    break
    # update_data_mysql(dates[0], stock_name_cleaned, combined_data)  # Update with the first date or customize as needed
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                            open        high         low       close  volume  \
# start_Time
# 2024-10-14 09:15:00  852.049988  852.049988  844.150024  844.400024   67071
# 2024-10-14 09:30:00  844.700012  850.650024  844.000000  849.700012  138951
# 2024-10-14 09:45:00  849.700012  854.250000  848.950012  853.500000  113990
# 2024-10-14 10:00:00  853.549988  854.750000  849.500000  850.650024   93449
# 2024-10-14 10:15:00  850.650024  853.099976  849.200012  851.799988   50511
# ...                         ...         ...         ...         ...     ...
# 2024-10-24 14:15:00  800.900024  800.900024  798.099976  799.500000   76162
# 2024-10-24 14:30:00  799.599976  801.650024  799.599976  800.849976   85824
# 2024-10-24 14:45:00  800.849976  803.250000  799.900024  800.250000   95867
# 2024-10-24 15:00:00  800.299988  802.200012  800.099976  801.400024  194993
# 2024-10-24 15:15:00  801.400024  802.900024  800.549988  802.700012  309625
#
#                             %K         %D
# start_Time
# 2024-10-14 09:15:00        NaN        NaN
# 2024-10-14 09:30:00        NaN        NaN
# 2024-10-14 09:45:00        NaN        NaN
# 2024-10-14 10:00:00        NaN        NaN
# 2024-10-14 10:15:00        NaN        NaN
# ...                        ...        ...
# 2024-10-24 14:15:00   8.201694  34.391510
# 2024-10-24 14:30:00  33.333333  27.690018
# 2024-10-24 14:45:00  59.775713  33.770247
# 2024-10-24 15:00:00  93.109047  62.072698
# 2024-10-24 15:15:00  93.109047  81.997936
#
# [225 rows x 7 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\Komputer_Science\Summer After 8th sem\Kotak\my_env\lib\site-packages\mysql\connector\cursor.py:353, in MySQLCursor._process_params(self, params)
#     352 quote = self._connection.converter.quote
# --> 353 res = [to_mysql(value) for value in res]
#     354 res = [escape(value, sql_mode) for value in res]
#
# File d:\Komputer_Science\Summer After 8th sem\Kotak\my_env\lib\site-packages\mysql\connector\cursor.py:353, in <listcomp>(.0)
#     352 quote = self._connection.converter.quote
# --> 353 res = [to_mysql(value) for value in res]
#     354 res = [escape(value, sql_mode) for value in res]
#
# File d:\Komputer_Science\Summer After 8th sem\Kotak\my_env\lib\site-packages\mysql\connector\conversion.py:246, in MySQLConverter.to_mysql(self, value)
#     245     return str(value).encode()
# --> 246 raise TypeError(
#     247     f"Python '{type_name}' cannot be converted to a MySQL type"
#     248 ) from None
#
# TypeError: Python 'timestamp' cannot be converted to a MySQL type
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[11], line 37
#      35 stock_name_cleaned = stock_name[:-3]
#      36 print(combined_data)
# ---> 37 update_data_mysql_without_date(stock_name_cleaned,combined_data)
#      38 break
#      39 # update_data_mysql(dates[0], stock_name_cleaned, combined_data)  # Update with the first date or customize as needed
#
# Cell In[10], line 293, in update_data_mysql_without_date(ticker, df)
#     290     percent_k = float(row['%K'])
#     291     percent_d = float(row["%D"])
# --> 293     cursor.execute("""
#     294         INSERT INTO stock_data_test_2 (ticker, date, timestamp, open, high, low, close, volume,percent_k,percent_d)
#     295         VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s,%s)
#     296         ON DUPLICATE KEY UPDATE
#     297             open = VALUES(open),
#     298             high = VALUES(high),
#     299             low = VALUES(low),
#     300             close = VALUES(close),
#     301             volume = VALUES(volume),
#     302             percent_k = VALUES(percent_k),
#     303             percent_d = VALUES(percent_d)
#     304     """, (ticker, date, timestamp, open_val, high_val, low_val, close_val, volume_val,percent_k,percent_d))
#     306 conn.commit()
#
# File d:\Komputer_Science\Summer After 8th sem\Kotak\my_env\lib\site-packages\mysql\connector\cursor.py:519, in MySQLCursor.execute(self, operation, params, multi)
#     517     stmt = _bytestr_format_dict(stmt, self._process_params_dict(params))
#     518 elif isinstance(params, (list, tuple)):
# --> 519     psub = _ParamSubstitutor(self._process_params(params))
#     520     stmt = RE_PY_PARAM.sub(psub, stmt)
#     521     if psub.remaining != 0:
#
# File d:\Komputer_Science\Summer After 8th sem\Kotak\my_env\lib\site-packages\mysql\connector\cursor.py:360, in MySQLCursor._process_params(self, params)
#     355     res = [
#     356         quote(value) if not isinstance(params[i], Decimal) else value
#     357         for i, value in enumerate(res)
#     358     ]
#     359 except Exception as err:
# --> 360     raise ProgrammingError(
#     361         f"Failed processing format-parameters; {err}"
#     362     ) from err
#     363 return tuple(res)
#
# ProgrammingError: Failed processing format-parameters; Python 'timestamp' cannot be converted to a MySQL type

# %%
# df = get_data("2024-10-14", "DLF.NS")

# ticker = "DLF.NS"
# date = "2024-10-14"

# %%
data_new = get_data("2024-10-14","PEL.NS")
# print(data_new)

data_new = data_new.reset_index(drop=True)
data_new['%K'], data_new['%D'] = StochRSI(data_new['close'])
print(data_new)

generate_signal_mysql("PEL", 'sell',data_new)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#            open         high          low        close  volume         %K  \
# 0   1080.250000  1084.099976  1075.150024  1075.199951       0        NaN
# 1   1075.150024  1075.150024  1069.199951  1072.900024    9202        NaN
# 2   1072.000000  1075.150024  1072.000000  1074.650024   10327        NaN
# 3   1074.650024  1074.900024  1072.000000  1072.000000    7240        NaN
# 4   1072.599976  1073.150024  1070.500000  1070.500000   12761        NaN
# ..          ...          ...          ...          ...     ...        ...
# 70  1095.800049  1096.250000  1093.050049  1095.900024   65425  63.796002
# 71  1096.500000  1096.849976  1095.000000  1095.400024   29794  65.804849
# 72  1095.400024  1098.599976  1095.000000  1097.449951   26481  67.765643
# 73  1098.000000  1098.500000  1095.050049  1096.699951   17314  59.732470
# 74  1096.099976  1098.000000  1095.000000  1095.699951   11949  46.937999
#
#            %D
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 70  57.393230
# 71  62.064320
# 72  65.788831
# 73  64.434321
# 74  58.145371
#
# [75 rows x 7 columns]
# Signal not updated: Time gap too small

# %%
generate_signal(1244,"S")

# %%
df2 = get_dhan_data("3499")
print(df2)

# %%
import time
import datetime



query_for_yf_names = "select yf_name from stocks"

cursor.execute(query_for_yf_names)


result = cursor.fetchall()

dates = [   "2024-10-24"  , "2024-10-25" , "2024-10-28" , "2024-10-29" , "2024-10-30" , "2024-11-04" , "2024-11-05" , "2024-11-06" , "2024-11-07" , "2024-11-08" , "2024-11-11" , "2024-11-12"   , "2024-11-13" ,"2024-11-14"  ]

# dates = [ "2024-10-23" , "2024-10-24"  , "2024-10-25"  ]



yf_name_list = [row[0] for row in result]

while True:
    current_time = datetime.datetime.now().time()
    if  (current_time >= datetime.time(9, 0) and current_time <= datetime.time(15,0) ):

        for stock_name in yf_name_list:
            
            combined_data = get_data(dates[0],stock_name)
            # print(type(combined_data))
            for date in dates:
                data = get_data(date,stock_name)
                # print(type(data))
                combined_data = pd.concat([combined_data,data])
            
            query = "select stock_number from stocks where yf_name=%s"
            cursor.execute(query,(stock_name,))
            result = cursor.fetchall()
            token = result[0][0]
            dhan_security_code = str(token)
            dhan_data = get_dhan_data(dhan_security_code)
            # query_for_yf_names = "select stock_number from stocks where yf_name=%s"
            # cursor.execute(query_for_yf_names,("ABC",))
            
            # dhan_data = aggregate_to_15min_df(dhan_data)
            combined_data = pd.concat([combined_data,dhan_data])
            combined_data = aggregate_to_15min_df(combined_data)
            # combined_data = aggregate_to_5min_df(combined_data)
            combined_data = combined_data.reset_index(drop=True)
            
            data_new = combined_data
            data_new['%K'], data_new['%D'] = StochRSI(data_new['close'])
            # print(check_sell_signal(combined_data)
            stock_name_here = stock_name[:-3]
            if stock_name_here == "PEL":
                print(data_new.iloc[-1]['%K'])
            if check_sell_signal(data_new)==True:
                generate_signal_mysql(stock_name_here, 'sell',data_new)
            elif check_buy_signal(data_new)==True:
                generate_signal_mysql(stock_name_here, 'buy',data_new)
            
            time.sleep(2)
        time.sleep(20)
            
    else:
        print("Markets are closed")
        break
        
    # print(combined_data)


# print(combined_data)
        


# print(yf_name_list)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 36.5408883276294
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 27.966769522416275
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 30.42366560879304
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 35.912818154718984
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 83.88157273293136
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 83.78198789777966
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 60
#      57         elif check_buy_signal(data_new)==True:
#      58             generate_signal_mysql(stock_name_here, 'buy',data_new)
# ---> 60         time.sleep(2)
#      61     time.sleep(20)
#      63 else:
#
# KeyboardInterrupt:

# %%
df = get_data("2024-10-10" , "DLF.NS")
print(df)
print("hi")
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                            open        high         low       close  volume
# start_Time
# 2024-10-10 09:15:00  857.900024  875.700012  857.900024  869.000000       0
# 2024-10-10 09:20:00  869.250000  875.549988  866.750000  872.500000  257148
# 2024-10-10 09:25:00  872.599976  872.700012  868.000000  871.250000  123194
# 2024-10-10 09:30:00  871.650024  878.700012  871.599976  873.000000  256812
# 2024-10-10 09:35:00  872.849976  875.000000  870.349976  871.349976   99084
# ...                         ...         ...         ...         ...     ...
# 2024-10-10 15:05:00  860.250000  860.450012  858.400024  859.250000   56999
# 2024-10-10 15:10:00  859.799988  860.000000  859.049988  859.500000   82757
# 2024-10-10 15:15:00  859.400024  862.099976  858.549988  861.700012  216793
# 2024-10-10 15:20:00  861.900024  863.000000  860.400024  862.150024  100186
# 2024-10-10 15:25:00  862.650024  863.000000  860.000000  862.000000   95230
#
# [75 rows x 5 columns]
# hi

# %%
query = "select stock_number from stocks where yf_name=%s"
cursor.execute(query,(stock_name,))
result = cursor.fetchall()
token = result[0][0]
dhan_security_code = str(token)
dhan_data = get_dhan_data(dhan_security_code)
print(dhan_data)

# %%
data = dhan.intraday_minute_data(
    security_id='3499',
    exchange_segment='NSE_EQ',
    instrument_type='EQUITY'
)
# print(data)
data = data['data']
# print(da)
df1 = pd.DataFrame(data)
# print(df1)
# print(data)
df1['start_Time'] = df1['start_Time'].apply(dhan.convert_to_date_time)
# print(df.head(152))
# data = aggregate_to_15min(data)
# print("----------------------------------------------------------")
# df = pd.DataFrame(data)
# df['start_Time'] = df['start_Time'].apply(dhan.convert_to_date_time)
# # df['start_Time'] = df['start_Time'].apply(dhan.convert_to_date_time)
df1.set_index('start_Time', inplace=True)
print(df1)

# %%
query_for_yf_names = "select stock_number from stocks where yf_name=%s"
# cursor.execute(query_for_yf_names,("ABC",))
cursor.execute(query_for_yf_names,(,))
result = cursor.fetchall()
token = result[0][0]

# %%
# import numpy as np
# import pandas as pd

# # Function to calculate RSI using Wilder's smoothing method
# def RSI(series, period=14):
#     delta = series.diff()
#     gain = delta.where(delta > 0, 0).fillna(0)
#     loss = -delta.where(delta < 0, 0).fillna(0)

#     # Use exponential weighted moving average with alpha=1/period
#     avg_gain = gain.ewm(alpha=1/period, adjust=False).mean()
#     avg_loss = loss.ewm(alpha=1/period, adjust=False).mean()

#     rs = avg_gain / avg_loss
#     rsi = 100 - (100 / (1 + rs))
#     return rsi

# # Function to calculate Stochastic RSI similar to TradingView
# def StochRSI(series, period=14, smoothK=3, smoothD=3):
#     rsi = RSI(series, period)
#     stoch_rsi = (rsi - rsi.rolling(window=period).min()) / \
#                 (rsi.rolling(window=period).max() - rsi.rolling(window=period).min())
#     stoch_rsi *= 100  # Convert to percentage

#     # Use exponential moving averages for smoothing %K and %D
#     k = stoch_rsi.ewm(span=smoothK, adjust=False).mean()  # %K line
#     d = k.ewm(span=smoothD, adjust=False).mean()          # %D line

#     return k, d

# %% [markdown]
# # For testing the data

# %%
import time
import datetime
import matplotlib.pyplot as plt
import mplfinance as mpf


# query_for_yf_names = "select yf_name from stocks"
yf_name_of_stock = "DLF.NS"

# cursor.execute(query_for_yf_names)


# result = cursor.fetchall()

dates =  [  "2024-10-17" , "2024-10-18" , "2024-10-21" ,"2024-10-22", "2024-10-23" , "2024-10-24"  , "2024-10-25" , "2024-10-28" , "2024-10-29" ,"2024-10-30" , "2024-10-31" , "2024-11-04"]
combined_data = get_data(dates[0],yf_name_of_stock)
combined_data = combined_data.iloc[0:0]
for date in dates:
    data = get_data(date,yf_name_of_stock)
    # print(type(data))
    combined_data = pd.concat([combined_data,data])
                
    # combined_data = combined_data.reset_index(drop=True)
    combined_data = aggregate_to_15min_df(combined_data)
    print(combined_data)

    data_new = combined_data
    # print(data_new)
    data_new['%K'], data_new['%D'] = StochRSI(data_new['close'])
    
# add todays date here
data_new_1 = data_new[data_new.index.date == pd.to_datetime('2024-11-04').date()]
print(data_new_1)
stochastic_plot = [

mpf.make_addplot((data_new_1[['%K', '%D']]), ylim=[0, 100], panel=2, ylabel='Stoch')

]
# print(data2)
mpf.plot(data_new_1, type='candle', volume=True, addplot = stochastic_plot)

csv_file_path = 'ohlc_with_k_d.csv'
data_new.to_csv(csv_file_path)



# yf_name_list = [row[0] for row in result]

# while True:
#     current_time = datetime.datetime.now().time()
#     if current_time >= datetime.time(9, 0) and current_time <= datetime.time(15,15):

#         for stock_name in yf_name_list:
            
#             combined_data = get_data(dates[0],stock_name)
#             # print(type(combined_data))
#             for date in dates:
#                 data = get_data(date,stock_name)
#                 # print(type(data))
#                 combined_data = pd.concat([combined_data,data])
                
#             combined_data = combined_data.reset_index(drop=True)
#             data_new = combined_data
#             data_new['%K'], data_new['%D'] = StochRSI(data_new['close'])
#             # print(check_sell_signal(combined_data)
#             stock_name_here = stock_name[:-3]
#             if check_sell_signal(combined_data)==True:
#                 generate_signal(stock_name_here, 'sell')
#             else:
#                 time.sleep(10)
#     else:
#         print("Markets are closed")
#         break
        
    # print(combined_data)


# print(combined_data)
        


# print(yf_name_list)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# 2024-10-17 10:30:00  860.450012  863.900024  858.200012  863.549988  194822
# 2024-10-17 10:45:00  863.549988  864.799988  860.700012  861.349976  173787
# 2024-10-17 11:00:00  861.349976  861.349976  856.799988  857.200012  145256
# 2024-10-17 11:15:00  857.400024  860.000000  855.049988  856.700012  135133
# 2024-10-17 11:30:00  855.900024  859.549988  855.750000  856.400024  117059
# 2024-10-17 11:45:00  856.400024  856.750000  852.950012  855.849976  154906
# 2024-10-17 12:00:00  855.849976  860.000000  855.500000  859.750000  145826
# 2024-10-17 12:15:00  859.750000  861.349976  858.099976  860.900024   97422
# 2024-10-17 12:30:00  860.799988  863.099976  860.799988  861.000000  116074
# 2024-10-17 12:45:00  860.900024  865.450012  860.000000  864.150024  187894
# 2024-10-17 13:00:00  864.599976  865.349976  861.849976  863.150024   86741
# 2024-10-17 13:15:00  863.000000  863.599976  859.299988  860.299988  119823
# 2024-10-17 13:30:00  860.500000  863.900024  859.950012  861.599976   87806
# 2024-10-17 13:45:00  861.599976  861.599976  857.200012  857.700012   93984
# 2024-10-17 14:00:00  857.950012  859.650024  855.299988  856.500000  251133
# 2024-10-17 14:15:00  856.650024  864.599976  856.200012  863.200012  137242
# 2024-10-17 14:30:00  862.650024  864.750000  860.299988  861.849976  107287
# 2024-10-17 14:45:00  861.250000  862.000000  859.400024  860.599976  137571
# 2024-10-17 15:00:00  860.549988  864.049988  860.000000  861.900024  195903
# 2024-10-17 15:15:00  861.900024  862.549988  857.599976  859.000000  359153
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# 2024-10-17 10:30:00  860.450012  863.900024  858.200012  863.549988  194822
# 2024-10-17 10:45:00  863.549988  864.799988  860.700012  861.349976  173787
# 2024-10-17 11:00:00  861.349976  861.349976  856.799988  857.200012  145256
# 2024-10-17 11:15:00  857.400024  860.000000  855.049988  856.700012  135133
# 2024-10-17 11:30:00  855.900024  859.549988  855.750000  856.400024  117059
# 2024-10-17 11:45:00  856.400024  856.750000  852.950012  855.849976  154906
# 2024-10-17 12:00:00  855.849976  860.000000  855.500000  859.750000  145826
# 2024-10-17 12:15:00  859.750000  861.349976  858.099976  860.900024   97422
# 2024-10-17 12:30:00  860.799988  863.099976  860.799988  861.000000  116074
# 2024-10-17 12:45:00  860.900024  865.450012  860.000000  864.150024  187894
# 2024-10-17 13:00:00  864.599976  865.349976  861.849976  863.150024   86741
# 2024-10-17 13:15:00  863.000000  863.599976  859.299988  860.299988  119823
# 2024-10-17 13:30:00  860.500000  863.900024  859.950012  861.599976   87806
# 2024-10-17 13:45:00  861.599976  861.599976  857.200012  857.700012   93984
# 2024-10-17 14:00:00  857.950012  859.650024  855.299988  856.500000  251133
# 2024-10-17 14:15:00  856.650024  864.599976  856.200012  863.200012  137242
# 2024-10-17 14:30:00  862.650024  864.750000  860.299988  861.849976  107287
# 2024-10-17 14:45:00  861.250000  862.000000  859.400024  860.599976  137571
# 2024-10-17 15:00:00  860.549988  864.049988  860.000000  861.900024  195903
# 2024-10-17 15:15:00  861.900024  862.549988  857.599976  859.000000  359153
# 2024-10-18 09:15:00  856.049988  856.049988  846.750000  849.950012  181372
# 2024-10-18 09:30:00  850.150024  859.650024  850.150024  854.500000  186101
# 2024-10-18 09:45:00  854.500000  861.349976  851.750000  852.849976  126692
# 2024-10-18 10:00:00  852.450012  859.900024  850.400024  858.799988   82126
# 2024-10-18 10:15:00  858.500000  864.000000  858.299988  863.500000   92435
# 2024-10-18 10:30:00  863.450012  865.000000  862.000000  862.200012   75638
# 2024-10-18 10:45:00  862.349976  864.950012  862.250000  862.849976   49754
# 2024-10-18 11:00:00  863.299988  867.000000  861.500000  866.349976   76758
# 2024-10-18 11:15:00  866.150024  868.700012  863.000000  868.299988   83424
# 2024-10-18 11:30:00  868.299988  870.650024  866.750000  868.849976   68988
# 2024-10-18 11:45:00  868.849976  869.900024  866.200012  869.799988   67239
# 2024-10-18 12:00:00  869.799988  872.799988  869.200012  870.400024   99152
# 2024-10-18 12:15:00  870.500000  874.349976  870.400024  872.450012   64592
# 2024-10-18 12:30:00  872.250000  873.900024  872.000000  872.599976   40175
# 2024-10-18 12:45:00  872.799988  873.900024  870.400024  872.950012   54235
# 2024-10-18 13:00:00  873.000000  873.150024  871.200012  871.950012   46612
# 2024-10-18 13:15:00  871.650024  874.400024  871.250000  873.500000   44748
# 2024-10-18 13:30:00  873.500000  874.450012  872.799988  874.000000   37931
# 2024-10-18 13:45:00  874.299988  875.250000  873.049988  874.549988   68648
# 2024-10-18 14:00:00  874.549988  875.900024  873.950012  875.500000   59879
# 2024-10-18 14:15:00  875.250000  879.750000  874.650024  879.099976  134765
# 2024-10-18 14:30:00  879.349976  880.150024  876.549988  879.299988   85268
# 2024-10-18 14:45:00  879.299988  880.299988  878.200012  879.200012   81216
# 2024-10-18 15:00:00  879.650024  879.650024  874.599976  875.150024  235428
# 2024-10-18 15:15:00  874.650024  875.150024  873.150024  874.000000  207943
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-10-21 14:15:00  861.599976  863.549988  861.049988  861.450012   26429
# 2024-10-21 14:30:00  861.650024  864.750000  861.500000  861.950012   35777
# 2024-10-21 14:45:00  861.950012  861.950012  859.099976  860.049988   58035
# 2024-10-21 15:00:00  860.250000  864.000000  860.150024  860.500000  121512
# 2024-10-21 15:15:00  860.750000  862.549988  857.299988  858.000000  185787
#
# [75 rows x 5 columns]
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-10-22 14:15:00  823.450012  823.450012  819.400024  820.700012  168955
# 2024-10-22 14:30:00  820.200012  821.750000  818.599976  819.299988  108904
# 2024-10-22 14:45:00  819.400024  822.549988  815.500000  815.799988  177427
# 2024-10-22 15:00:00  815.799988  818.650024  813.049988  813.299988  387905
# 2024-10-22 15:15:00  813.049988  816.900024  813.000000  815.900024  394570
#
# [100 rows x 5 columns]
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-10-23 14:15:00  810.150024  810.950012  805.900024  807.200012  295297
# 2024-10-23 14:30:00  807.000000  808.049988  804.349976  804.650024  279501
# 2024-10-23 14:45:00  804.650024  806.900024  803.500000  806.299988  251284
# 2024-10-23 15:00:00  806.500000  807.500000  804.700012  805.049988  304945
# 2024-10-23 15:15:00  805.099976  806.400024  803.150024  805.349976  538441
#
# [125 rows x 5 columns]
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-10-24 14:15:00  800.900024  800.900024  798.099976  799.500000   76162
# 2024-10-24 14:30:00  799.599976  801.650024  799.599976  800.849976   85824
# 2024-10-24 14:45:00  800.849976  803.250000  799.900024  800.250000   95867
# 2024-10-24 15:00:00  800.299988  802.200012  800.099976  801.400024  194993
# 2024-10-24 15:15:00  801.400024  802.900024  800.549988  802.700012  309625
#
# [150 rows x 5 columns]
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-10-25 14:15:00  772.700012  774.799988  771.500000  773.500000   56925
# 2024-10-25 14:30:00  773.549988  775.349976  771.799988  773.950012   59211
# 2024-10-25 14:45:00  773.750000  776.650024  773.200012  774.900024   91876
# 2024-10-25 15:00:00  774.799988  778.500000  774.799988  776.200012  204182
# 2024-10-25 15:15:00  775.849976  779.750000  775.099976  777.000000  176359
#
# [175 rows x 5 columns]
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-10-28 14:15:00  825.950012  827.849976  825.849976  826.650024  105994
# 2024-10-28 14:30:00  826.650024  828.349976  825.099976  826.099976  329684
# 2024-10-28 14:45:00  826.049988  826.349976  824.099976  825.150024  258878
# 2024-10-28 15:00:00  824.799988  825.349976  820.950012  824.450012  562883
# 2024-10-28 15:15:00  824.400024  825.349976  820.599976  821.549988  600609
#
# [200 rows x 5 columns]
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-10-29 14:15:00  833.250000  834.049988  832.150024  832.599976   63637
# 2024-10-29 14:30:00  832.650024  832.650024  830.650024  831.849976   81153
# 2024-10-29 14:45:00  831.799988  833.700012  831.750000  831.750000  141330
# 2024-10-29 15:00:00  831.500000  834.000000  831.099976  833.000000  115106
# 2024-10-29 15:15:00  833.150024  833.250000  830.500000  832.000000  179507
#
# [225 rows x 5 columns]
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-10-30 14:15:00  826.750000  828.900024  826.750000  828.500000   86288
# 2024-10-30 14:30:00  828.500000  829.650024  827.750000  829.299988  104861
# 2024-10-30 14:45:00  829.299988  829.799988  828.000000  828.000000   54693
# 2024-10-30 15:00:00  827.950012  828.650024  826.549988  827.450012  295599
# 2024-10-30 15:15:00  827.500000  827.900024  823.000000  826.400024  436372
#
# [250 rows x 5 columns]
# [*********************100%%**********************]  1 of 1 completed
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-10-31 14:15:00  816.900024  817.250000  815.799988  815.799988   32722
# 2024-10-31 14:30:00  815.849976  818.700012  815.099976  817.950012   64249
# 2024-10-31 14:45:00  817.950012  823.500000  817.950012  822.700012  285752
# 2024-10-31 15:00:00  822.900024  823.950012  819.650024  821.299988  349862
# 2024-10-31 15:15:00  821.150024  821.299988  816.700012  819.000000  596946
#
# [275 rows x 5 columns]
#                            open        high         low       close  volume
# start_Time
# 2024-10-17 09:15:00  888.000000  888.000000  881.250000  881.500000  187011
# 2024-10-17 09:30:00  881.599976  881.599976  869.599976  871.799988  258130
# 2024-10-17 09:45:00  871.500000  871.500000  864.000000  864.400024  225913
# 2024-10-17 10:00:00  864.400024  866.650024  858.500000  861.950012  249075
# 2024-10-17 10:15:00  862.150024  862.700012  855.250000  860.500000  210121
# ...                         ...         ...         ...         ...     ...
# 2024-11-04 14:15:00  791.000000  791.849976  789.049988  790.200012  112317
# 2024-11-04 14:30:00  790.200012  795.000000  790.150024  790.950012  164249
# 2024-11-04 14:45:00  790.950012  791.900024  788.500000  789.000000  136509
# 2024-11-04 15:00:00  789.000000  791.000000  788.150024  789.549988  293358
# 2024-11-04 15:15:00  789.549988  792.400024  788.549988  792.400024  355837
#
# [300 rows x 5 columns]
#                            open        high         low       close  volume  \
# start_Time
# 2024-11-04 09:15:00  824.700012  824.700012  813.799988  814.299988  100423
# 2024-11-04 09:30:00  813.549988  816.599976  810.599976  811.700012  136943
# 2024-11-04 09:45:00  811.500000  811.700012  805.549988  806.599976  192020
# 2024-11-04 10:00:00  806.349976  807.849976  800.000000  801.250000  258032
# 2024-11-04 10:15:00  801.250000  803.400024  797.950012  799.200012  199477
# 2024-11-04 10:30:00  799.200012  802.000000  795.349976  797.349976  150290
# 2024-11-04 10:45:00  797.750000  799.000000  795.900024  796.599976   79881
# 2024-11-04 11:00:00  796.400024  796.799988  792.599976  796.750000  107445
# 2024-11-04 11:15:00  796.500000  800.250000  793.000000  797.849976   80152
# 2024-11-04 11:30:00  797.950012  798.849976  795.000000  796.700012   64387
# 2024-11-04 11:45:00  796.650024  798.000000  795.049988  797.150024   40025
# 2024-11-04 12:00:00  796.700012  798.950012  794.250000  794.450012   70046
# 2024-11-04 12:15:00  794.799988  795.849976  791.900024  794.000000   87321
# 2024-11-04 12:30:00  793.849976  795.849976  793.400024  794.549988   43570
# 2024-11-04 12:45:00  794.549988  795.099976  792.200012  792.349976   41049
# 2024-11-04 13:00:00  792.400024  794.900024  791.750000  794.500000  102081
# 2024-11-04 13:15:00  794.549988  794.750000  789.250000  789.700012  179165
# 2024-11-04 13:30:00  789.700012  791.000000  788.500000  789.049988  108502
# 2024-11-04 13:45:00  789.049988  792.299988  788.799988  790.700012   98541
# 2024-11-04 14:00:00  790.900024  792.900024  789.299988  791.000000  107956
# 2024-11-04 14:15:00  791.000000  791.849976  789.049988  790.200012  112317
# 2024-11-04 14:30:00  790.200012  795.000000  790.150024  790.950012  164249
# 2024-11-04 14:45:00  790.950012  791.900024  788.500000  789.000000  136509
# 2024-11-04 15:00:00  789.000000  791.000000  788.150024  789.549988  293358
# 2024-11-04 15:15:00  789.549988  792.400024  788.549988  792.400024  355837
#
#                             %K         %D
# start_Time
# 2024-11-04 09:15:00  51.337014  74.335579
# 2024-11-04 09:30:00  24.497529  51.332705
# 2024-11-04 09:45:00   6.506776  27.447106
# 2024-11-04 10:00:00   0.000000  10.334768
# 2024-11-04 10:15:00   0.000000   2.168925
# 2024-11-04 10:30:00   0.000000   0.000000
# 2024-11-04 10:45:00   0.000000   0.000000
# 2024-11-04 11:00:00   4.393496   1.464499
# 2024-11-04 11:15:00  37.726829  14.040108
# 2024-11-04 11:30:00  63.895374  35.338566
# 2024-11-04 11:45:00  92.835211  64.819138
# 2024-11-04 12:00:00  77.071988  77.934191
# 2024-11-04 12:15:00  64.367943  78.091714
# 2024-11-04 12:30:00  61.631046  67.690326
# 2024-11-04 12:45:00  47.611321  57.870103
# 2024-11-04 13:00:00  67.480154  58.907507
# 2024-11-04 13:15:00  48.192599  54.428025
# 2024-11-04 13:30:00  53.829471  56.500741
# 2024-11-04 13:45:00  49.934281  50.652117
# 2024-11-04 14:00:00  71.863971  58.542574
# 2024-11-04 14:15:00  88.457213  70.085155
# 2024-11-04 14:30:00  92.352403  84.224529
# 2024-11-04 14:45:00  76.123606  85.644407
# 2024-11-04 15:00:00  70.180976  79.552328
# 2024-11-04 15:15:00  70.180976  72.161853
