# %%
from neo_api_client import NeoAPI
import pandas as pd
import datetime as dt
from dateutil.relativedelta import relativedelta

# %%
CS = "dFZGrIDg8hEXkXkOfPfnVus8LDca"
CK = "N3Mt8S8yWurhevxOUC7L8HsQvdwa"

MOB_NO = "+917058287084"

PASSWORD = "RohanPawar@1"

MPIN = "369121"

# %%
def on_error(error_message):
    print(error_message)

def on_close(message):
    print(message)
    
def on_open(message):
    print(message)


client = NeoAPI(consumer_key=CK, consumer_secret=CS, environment='prod',
                access_token=None, neo_fin_key=None)

client.login(mobilenumber=MOB_NO,password=PASSWORD )
client.session_2fa(OTP=MPIN)
# Out:
# {"data": {"access_token": "eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..fya34nE8RWLBYAlFI7EYWW7xa56EXobYvWhy5QMYj1txRpzoYeXuNVwhiLccpMb24hGaOxm29wK8tNH7w3rNjkyd0EoTQu25ZjRSLwWKp1etj5XjBW27Iqkq-civDkS4u87XWU_iAW4lOCpbCZB5nobzneu1BPn5k62S4yP8-TUzS84YSG80Umm_knqwJqxIr5afa2Okt-tKeNx8bVFVbuqbHh45LsSxlByOnzcg8XnehUxPASelmEx3GiwbnrVDzWs9KLviNu3NMnfbxXTQXk8S0k9KPc0IkaldxZFLJd7a7Exir9v2rHwDz5JTxf3XWC7ZDU19hpXASo
# ...

# %%
import datetime


current_time = datetime.datetime.now().time()

print(current_time.strftime("%S"))
# Out:
# 01

# %%
import json

data = {
   "tid":"server1_4100998",
   "stat":"Ok",
   "stCode":200,
   "data":[
      {
         "brkClnt":"08081",
         "ordValDt":"NA",
         "exUsrInfo":"NA",
         "mfdBy":"NA",
         "vendorCode":"",
         "rmk":"--",
         "odCrt":"NA",
         "ordSrc":"ADMINCPPAPI_TRADEAPI",
         "sipInd":"NA",
         "prc":"0.00",
         "prcTp":"MKT",
         "cnlQty":0,
         "uSec":"532878",
         "classification":"0",
         "mktPro":"0.00",
         "ordEntTm":"29-Jul-2024 09:38:26",
         "reqId":"1",
         "algSeqNo":"NA",
         "qty":1,
         "unFldSz":0,
         "mktProPct":"--",
         "algCat":"NA",
         "exOrdId":"1300000007875968",
         "dscQty":0,
         "actId":"X79YR",
         "expDt":"NA",
         "trgPrc":"0.00",
         "tok":"2963",
         "symOrdId":"NA",
         "fldQty":1,
         "ordDtTm":"29-Jul-2024 09:38:26",
         "avgPrc":"148.13",
         "locId":"111111111111100",
         "algId":"NA",
         "stat":"Ok",
         "prod":"MIS",
         "exSeg":"nse_cm",
         "GuiOrdId":"1722226106-508930-GCZPM4788L-ADMINAPI",
         "usrId":"GCZPM4788L",
         "rptTp":"NA",
         "exCfmTm":"29-Jul-2024 09:38:26",
         "hsUpTm":"2024/07/29 19:46:44",
         "ordGenTp":"NA",
         "vldt":"DAY",
         "tckSz":"0.01",
         "ordSt":"complete",
         "trnsTp":"B",
         "refLmtPrc":0.0,
         "coPct":0.0,
         "nOrdNo":"240729000212671",
         "ordAutSt":"NA",
         "strategyCode":"NA",
         "rejRsn":"--",
         "boeSec":1722226106,
         "expDtSsb":"--",
         "dscQtyPct":"0",
         "stkPrc":"0.00",
         "sym":"SAIL",
         "trdSym":"SAIL-EQ",
         "multiplier":"1",
         "precision":"2",
         "noMktProFlg":"0.00",
         "genNum":"1",
         "series":"EQ",
         "prcNum":"1",
         "genDen":"1",
         "brdLtQty":"1",
         "mktProFlg":"0.00",
         "defMktProV":"0.00",
         "lotSz":"1",
         "minQty":0,
         "optTp":"XX",
         "prcDen":"1"
      },
      {
         "brkClnt":"08081",
         "ordValDt":"NA",
         "exUsrInfo":"NA",
         "mfdBy":"NA",
         "vendorCode":"",
         "rmk":"--",
         "odCrt":"NA",
         "ordSrc":"ADMINCPPAPI_TRADEAPI",
         "sipInd":"NA",
         "prc":"0.00",
         "prcTp":"MKT",
         "cnlQty":0,
         "uSec":"076189",
         "classification":"0",
         "mktPro":"0.00",
         "ordEntTm":"29-Jul-2024 09:38:26",
         "reqId":"1",
         "algSeqNo":"NA",
         "qty":1,
         "unFldSz":0,
         "mktProPct":"--",
         "algCat":"NA",
         "exOrdId":"1300000007874197",
         "dscQty":0,
         "actId":"X79YR",
         "expDt":"NA",
         "trgPrc":"0.00",
         "tok":"2963",
         "symOrdId":"NA",
         "fldQty":1,
         "ordDtTm":"29-Jul-2024 09:38:26",
         "avgPrc":"148.06",
         "locId":"111111111111100",
         "algId":"NA",
         "stat":"Ok",
         "prod":"MIS",
         "exSeg":"nse_cm",
         "GuiOrdId":"1722226106-51963-GCZPM4788L-ADMINAPI",
         "usrId":"GCZPM4788L",
         "rptTp":"NA",
         "exCfmTm":"29-Jul-2024 09:38:26",
         "hsUpTm":"2024/07/29 19:46:44",
         "ordGenTp":"NA",
         "vldt":"DAY",
         "tckSz":"0.01",
         "ordSt":"complete",
         "trnsTp":"S",
         "refLmtPrc":0.0,
         "coPct":0.0,
         "nOrdNo":"240729000212631",
         "ordAutSt":"NA",
         "strategyCode":"NA",
         "rejRsn":"--",
         "boeSec":1722226106,
         "expDtSsb":"--",
         "dscQtyPct":"0",
         "stkPrc":"0.00",
         "sym":"SAIL",
         "trdSym":"SAIL-EQ",
         "multiplier":"1",
         "precision":"2",
         "noMktProFlg":"0.00",
         "genNum":"1",
         "series":"EQ",
         "prcNum":"1",
         "genDen":"1",
         "brdLtQty":"1",
         "mktProFlg":"0.00",
         "defMktProV":"0.00",
         "lotSz":"1",
         "minQty":0,
         "optTp":"XX",
         "prcDen":"1"
      },
      {
         "brkClnt":"08081",
         "ordValDt":"NA",
         "exUsrInfo":"NA",
         "mfdBy":"NA",
         "vendorCode":"",
         "rmk":"--",
         "odCrt":"NA",
         "ordSrc":"ADMINCPPAPI_MOB",
         "sipInd":"NA",
         "prc":"147.90",
         "prcTp":"L",
         "cnlQty":0,
         "uSec":"607508",
         "classification":"0",
         "mktPro":"0.00",
         "ordEntTm":"29-Jul-2024 09:38:25",
         "reqId":"1",
         "algSeqNo":"NA",
         "qty":1,
         "unFldSz":0,
         "mktProPct":"--",
         "algCat":"NA",
         "exOrdId":"1300000007872584",
         "dscQty":0,
         "actId":"X79YR",
         "expDt":"NA",
         "trgPrc":"0.00",
         "tok":"2963",
         "symOrdId":"NA",
         "fldQty":1,
         "ordDtTm":"29-Jul-2024 09:38:25",
         "avgPrc":"148.06",
         "locId":"333333333333100",
         "algId":"NA",
         "stat":"Ok",
         "prod":"MIS",
         "exSeg":"nse_cm",
         "GuiOrdId":"1722226105-583632-GCZPM4788L-ADMINAPI",
         "usrId":"GCZPM4788L",
         "rptTp":"NA",
         "exCfmTm":"29-Jul-2024 09:38:25",
         "hsUpTm":"2024/07/29 19:46:44",
         "ordGenTp":"NA",
         "vldt":"DAY",
         "tckSz":"0.01",
         "ordSt":"complete",
         "trnsTp":"S",
         "refLmtPrc":0.0,
         "coPct":0.0,
         "nOrdNo":"240729000212576",
         "ordAutSt":"NA",
         "strategyCode":"NA",
         "rejRsn":"--",
         "boeSec":1722226105,
         "expDtSsb":"--",
         "dscQtyPct":"0",
         "stkPrc":"0.00",
         "sym":"SAIL",
         "trdSym":"SAIL-EQ",
         "multiplier":"1",
         "precision":"2",
         "noMktProFlg":"0.00",
         "genNum":"1",
         "series":"EQ",
         "prcNum":"1",
         "genDen":"1",
         "brdLtQty":"1",
         "mktProFlg":"0.00",
         "defMktProV":"0.00",
         "lotSz":"1",
         "minQty":0,
         "optTp":"XX",
         "prcDen":"1"
      }
   ]
}

print(data['data'][0]['avgPrc'])
# Out:
# 148.13

# %%
# to download the script master

url = client.scrip_master(exchange_segment='NSE')

df = pd.read_csv(url)

print(url)
# Out:
# https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2024-07-19/transformed/nse_cm.csv

# %%
df
# Out:
#       pSymbol pGroup pExchSeg  pInstType pSymbolName     pTrdSymbol
# 0        6531     IV   nse_cm        NaN        NHIT        NHIT-IV  \
# 1        6542     BL   nse_cm        NaN        NHIT        NHIT-BL
# 2        6545     EQ   nse_cm        NaN       NYKAA       NYKAA-EQ
# 3           1     SM   nse_cm        NaN    GOLDSTAR    GOLDSTAR-SM
# 4        6548     BL   nse_cm        NaN      GRPLTD      GRPLTD-BL
# ...       ...    ...      ...        ...         ...            ...
# 9123    13398     SG   nse_cm        NaN     768PN39     768PN39-SG
# 9124    13399     SG   nse_cm        NaN     767WB39     767WB39-SG
# 9125     6501     BE   nse_cm        NaN        IRIS        IRIS-BE
# 9126     6503     BL   nse_cm        NaN        IRIS        IRIS-BL
# 9127     6518     GB   nse_cm        NaN  SGBNV29VII  SGBNV29VII-GB
#
#       pOptionType   pScripRefKey         pISIN  pAssetCode  ...  dGenDen
# 0             NaN        NHIT-IV  INE0H7R23014         NaN  ...        1  \
# ...

# %%
list = [10,9,8]

for i in range(len(list)):
import daterime    print(list[i])
# Out:
# 10
# 9
# 8

# %%
import datetime

current_time = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
print(current_time)
# Out:
# 2024-10-25 09:27:45
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
try:
    # Place an order
    response = client.place_order(
        exchange_segment="nse_cm",          # Exchange segment for NSE cash market
        product="MIS",                      # Product type for cash and carry
        price="0",                          # Leave price empty for market order
        order_type="MKT",                  # Order type for market order
        quantity="1",                      # Quantity of the order (adjust as needed)
        validity="DAY",                    # Validity of the order
        trading_symbol="TATASTEEL-EQ",         # Trading symbol for Tata Steel
        transaction_type="B",              # Transaction type for buying
        amo="NO",                          # After market order (AMO) - NO for regular trading hours
        disclosed_quantity="0",            # Disclosed quantity
        market_protection="0",             # Market protection
        pf="N",                            # Protect flag (N for no protection)
        trigger_price="0",                 # Trigger price (not needed for market orders)
        tag=None                           # Optional tag for the order
    )
    print("Order placed successfully:", response)
except Exception as e:
    print("Exception when calling OrderApi->place_order: %s\n" % e)
# Out:
# Order placed successfully: {'stat': 'Ok', 'nOrdNo': '240719001734775', 'tid': 'server3_3315012', 'stCode': 200}

# %%
try:
    # Get all order details
    res = client.order_report()
    # Get particular details using order_id
    # client.order_history()   
    print(res)
    d1 = pd.DataFrame(res["data"])
    # print(d1)
except Exception as e:
    print("Exception when order report API->order_report: %s\n" % e)
# Out:
# {'tid': 'server3_3323844', 'stat': 'Ok', 'stCode': 200, 'data': [{'brkClnt': '--', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '0.00', 'prcTp': 'MKT', 'cnlQty': 0, 'uSec': '173585', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '--', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 1, 'unFldSz': 0, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': 'NA', 'dscQty': 0, 'actId': 'X79YR', 'expDt': 'NA', 'trgPrc': '0.00', 'tok': '3499', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '19-Jul-2024 20:44:32', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_cm', 'GuiOrdId': '1721402072-172701-GCZPM4788L-ADMINAPI', 'usrId': 'GCZPM4788L', 'rptTp': 'NA', 'exCfmTm': 'NA', 'hsUpTm': '2024/07/19 20:49:05', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.01', 'ordSt': 'rejected', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '24071900173477
# ...

# %%
import redis


responses = [
    {
        'type': 'stock_feed',
        'data': [
            {'tk': '383', 'ltp': '312.45', 'other_field': 'value'},
            {'tk': '1624', 'ltp': '168.20', 'other_field': 'value'},
            # Other responses...
        ]
    },
    {
        'type': 'stock_feed',
        'data': [
            {'tk': '383', 'ltp': '312.50', 'other_field': 'value'},
            {'tk': '21951', 'ltp': '117.37', 'other_field': 'value'},
            # Other responses...
        ]
    }
    # Additional responses...
]

# %%
# for holdings


try:
    res_h = client.holdings()
    print(res_h)

except Exception as e:
    print("Exception when calling Holdings->holdings: %s\n" % e)
# Out:
# {'data': [{'displaySymbol': 'MID150BEES', 'averagePrice': 204.7686, 'quantity': 2, 'exchangeSegment': 'nse_cm', 'exchangeIdentifier': '8506', 'holdingCost': 409.5372, 'mktValue': 437, 'scripId': 'e40d9e997059594d927680c22fe5b9d3226daa7e', 'instrumentToken': 18943, 'instrumentType': 'Equity', 'isAlternateScrip': False, 'closingPrice': 218.5, 'symbol': 'MID150BEES'}]}
